# %%
# %cd '/content/drive/My Drive/DGM'
# !ls -la
# Out:
# /content/drive/.shortcut-targets-by-id/1kDpR7ZDOioZwBxWQjbzZsfhTgwnaFFxm/DGM
# total 536796
# -rw------- 1 root root    107208 Oct 24 12:39 Board.h
# -rw------- 1 root root       150 Nov 15 20:47 compile.sh
# -rw------- 1 root root      1048 Nov 20 08:47 config.py
# -rw------- 1 root root      1540 Nov 19 18:21 dataloader.py
# -rw------- 1 root root   6298720 Nov 19 22:22 DGV0.h5
# -rw------- 1 root root      2554 Nov 19 22:22 DGV0_history
# -rw------- 1 root root     15320 Oct 24 12:39 Game.h
# -rw------- 1 root root 542497580 Nov 15 22:41 games.data
# -rw------- 1 root root     12273 Oct 24 16:29 golois.cpp
# -rw------- 1 root root    236328 Nov 19 13:13 golois.cpython-37m-x86_64-linux-gnu.so
# -rw------- 1 root root    236328 Nov 15 23:00 golois.cpython-38-x86_64-linux-gnu.so
# -rw------- 1 root root      2575 Nov 19 14:12 golois.py
# drwx------ 2 root root      4096 Nov 19 12:48 model_imgs
# -rw------- 1 root root      4707 Nov 19 20:36 model.py
# drwx------ 2 root root      4096 Nov 19 12:46 __pycache__
# -rw------- 1 root root      6420 Oct 24 12:39 Rzone.h
# -rw------- 1 root root    155264 Nov 20 10:44 train_dgm.ipynb
# -rw------- 1 root root      1742 Nov 19 20:36 train.py
# -rw------- 1 root root     86303 Nov 19 14:08 validation.data

# %%
# !python golois.py
# Out:
# getValidation
# r.shape = (10000, 19, 19, 31)
# nbExamples = 10000
# tcmalloc: large alloc 2400002048 bytes == 0x558c5e05a000 @  0x7f1508c5b887 0x7f147746d0d9 0x7f147747285f 0x7f147748706f 0x558c073b04b0 0x558c073b0240 0x558c074240f3 0x558c0741e9ee 0x558c0741e6f3 0x558c074e84c2 0x558c074e883d 0x558c074e86e6 0x558c074c0163 0x558c074bfe0c 0x7f1507a43bf7 0x558c074bfcea
# nbPositionsSGF = 29425326
# nbPositionsSGF = 29425326
# loading validation.data
# 2021-11-19 18:33:27.178634: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  board (InputLayer)             [(None, 19, 19, 31)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 19, 19, 64)   2048        ['board[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 64)   36928       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 64)   36928       ['conv2d_1[0][0]']
#
#  add (Add)                      (None, 19, 19, 64)   0           ['conv2d_2[0][0]',
#                                                                   'conv2d[0][0]']
#
#  re_lu (ReLU)                   (None, 19, 19, 64)   0           ['add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 19, 19, 64)  256         ['re_lu[0][0]']
#  alization)
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 64)   36928       ['conv2d_3[0][0]']
#
#  add_1 (Add)                    (None, 19, 19, 64)   0           ['conv2d_4[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 19, 19, 64)   0           ['add_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 19, 19, 64)  256         ['re_lu_1[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 64)   36928       ['conv2d_5[0][0]']
#
#  add_2 (Add)                    (None, 19, 19, 64)   0           ['conv2d_6[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 19, 19, 64)   0           ['add_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 19, 19, 64)  256         ['re_lu_2[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 19, 19, 64)   36928       ['conv2d_7[0][0]']
#
#  add_3 (Add)                    (None, 19, 19, 64)   0           ['conv2d_8[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 19, 19, 64)   0           ['add_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 19, 19, 64)  256         ['re_lu_3[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 19, 19, 64)   36928       ['conv2d_9[0][0]']
#
#  add_4 (Add)                    (None, 19, 19, 64)   0           ['conv2d_10[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 19, 19, 64)   0           ['add_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 19, 19, 64)  256         ['re_lu_4[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 19, 19, 64)   36928       ['conv2d_11[0][0]']
#
#  add_5 (Add)                    (None, 19, 19, 64)   0           ['conv2d_12[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 19, 19, 64)   0           ['add_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 19, 19, 64)  256         ['re_lu_5[0][0]']
#  rmalization)
#
#  conv2d_13 (Conv2D)             (None, 19, 19, 1)    64          ['batch_normalization_5[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['batch_normalization_5[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 361)          0           ['conv2d_13[0][0]']
#
#  dense (Dense)                  (None, 50)           3250        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  policy (Activation)            (None, 361)          0           ['flatten[0][0]']
#
#  value (Dense)                  (None, 1)            51          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 450,085
# Trainable params: 449,317
# Non-trainable params: 768
# __________________________________________________________________________________________________
# epoch 1
# r.shape = (10000, 19, 19, 31)
# nbExamples = 10000
# 79/79 [==============================] - 16s 96ms/step - loss: 5.4343 - policy_loss: 4.7349 - value_loss: 0.6935 - policy_categorical_accuracy: 0.0895 - value_mse: 0.1195
# epoch 2
# r.shape = (10000, 19, 19, 31)
# nbExamples = 10000
# 79/79 [==============================] - 7s 94ms/step - loss: 4.3846 - policy_loss: 3.6891 - value_loss: 0.6897 - policy_categorical_accuracy: 0.2178 - value_mse: 0.1175
# epoch 3
# r.shape = (10000, 19, 19, 31)
# nbExamples = 10000
# 79/79 [==============================] - 7s 94ms/step - loss: 4.1009 - policy_loss: 3.4064 - value_loss: 0.6886 - policy_categorical_accuracy: 0.2556 - value_mse: 0.1170
# epoch 4
# r.shape = (10000, 19, 19, 31)
# nbExamples = 10000
# 13/79 [===>..........................] - ETA: 6s - loss: 4.0475 - policy_loss: 3.3537 - value_loss: 0.6880 - policy_categorical_accuracy: 0.2825 - value_mse: 0.1176Traceback (most recent call last):
#   File "golois.py", line 64, in <module>
#     epochs=1, batch_size=batch)
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1216, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 910, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 942, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 3131, in __call__
#     filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     ctx, args, cancellation_manager=cancellation_manager))
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 603, in call
#     ctx=ctx)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     inputs, attrs, num_outputs)
# KeyboardInterrupt

# %%
# !python train.py
# Out:
# 2021-11-19 20:42:04.827416: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  board (InputLayer)             [(None, 19, 19, 31)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 19, 19, 64)   2048        ['board[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 64)   17920       ['board[0][0]']
#
#  batch_normalization (BatchNorm  (None, 19, 19, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  tf.nn.silu (TFOpLambda)        (None, 19, 19, 64)   0           ['batch_normalization[0][0]']
#
#  tf.nn.silu_1 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 19, 19, 64)   0           ['tf.nn.silu[0][0]',
#                                                                   'tf.nn.silu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  tf.nn.silu_2 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 64)          0           ['dropout[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 16)           1040        ['global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 64)           1088        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]',
#                                                                   'dense_1[0][0]']
#
#  add_1 (Add)                    (None, 19, 19, 64)   0           ['multiply[0][0]',
#                                                                   'add[0][0]']
#
#  tf.nn.silu_3 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 19, 19, 64)  256         ['tf.nn.silu_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  tf.nn.silu_4 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_6[0][0]']
#
#  global_max_pooling2d_1 (Global  (None, 64)          0           ['dropout_1[0][0]']
#  MaxPooling2D)
#
#  dense_2 (Dense)                (None, 16)           1040        ['global_max_pooling2d_1[0][0]']
#
#  dense_3 (Dense)                (None, 64)           1088        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'dense_3[0][0]']
#
#  add_2 (Add)                    (None, 19, 19, 64)   0           ['multiply_1[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  tf.nn.silu_5 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 19, 19, 64)  256         ['tf.nn.silu_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  tf.nn.silu_6 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_9[0][0]']
#
#  global_max_pooling2d_2 (Global  (None, 64)          0           ['dropout_2[0][0]']
#  MaxPooling2D)
#
#  dense_4 (Dense)                (None, 16)           1040        ['global_max_pooling2d_2[0][0]']
#
#  dense_5 (Dense)                (None, 64)           1088        ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_9[0][0]',
#                                                                   'dense_5[0][0]']
#
#  add_3 (Add)                    (None, 19, 19, 64)   0           ['multiply_2[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  tf.nn.silu_7 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_7[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 19, 19, 64)  256         ['conv2d_8[0][0]']
#  ormalization)
#
#  tf.nn.silu_8 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 19, 19, 64)  256         ['conv2d_9[0][0]']
#  ormalization)
#
#  dropout_3 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_12[0][0]']
#
#  global_max_pooling2d_3 (Global  (None, 64)          0           ['dropout_3[0][0]']
#  MaxPooling2D)
#
#  dense_6 (Dense)                (None, 16)           1040        ['global_max_pooling2d_3[0][0]']
#
#  dense_7 (Dense)                (None, 64)           1088        ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_12[0][0]',
#                                                                   'dense_7[0][0]']
#
#  add_4 (Add)                    (None, 19, 19, 64)   0           ['multiply_3[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  tf.nn.silu_9 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_4[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_9[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 19, 19, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  tf.nn.silu_10 (TFOpLambda)     (None, 19, 19, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 19, 19, 64)   36928       ['tf.nn.silu_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 19, 19, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  dropout_4 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_15[0][0]']
#
#  global_max_pooling2d_4 (Global  (None, 64)          0           ['dropout_4[0][0]']
#  MaxPooling2D)
#
#  dense_8 (Dense)                (None, 16)           1040        ['global_max_pooling2d_4[0][0]']
#
#  dense_9 (Dense)                (None, 64)           1088        ['dense_8[0][0]']
#
#  multiply_4 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_15[0][0]',
#                                                                   'dense_9[0][0]']
#
#  add_5 (Add)                    (None, 19, 19, 64)   0           ['multiply_4[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  tf.nn.silu_11 (TFOpLambda)     (None, 19, 19, 64)   0           ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_11[0][0]']
#  ormalization)
#
#  conv2d_12 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 19, 19, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_12 (TFOpLambda)     (None, 19, 19, 64)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 19, 19, 64)   36928       ['tf.nn.silu_12[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 19, 19, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  dropout_5 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_18[0][0]']
#
#  global_max_pooling2d_5 (Global  (None, 64)          0           ['dropout_5[0][0]']
#  MaxPooling2D)
#
#  dense_10 (Dense)               (None, 16)           1040        ['global_max_pooling2d_5[0][0]']
#
#  dense_11 (Dense)               (None, 64)           1088        ['dense_10[0][0]']
#
#  multiply_5 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_18[0][0]',
#                                                                   'dense_11[0][0]']
#
#  add_6 (Add)                    (None, 19, 19, 64)   0           ['multiply_5[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  tf.nn.silu_13 (TFOpLambda)     (None, 19, 19, 64)   0           ['add_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_13[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['batch_normalization_19[0][0]']
#  alAveragePooling2D)
#
#  conv2d_14 (Conv2D)             (None, 19, 19, 1)    64          ['batch_normalization_19[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization_20 (BatchN  (None, 19, 19, 1)   4           ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 64)          256         ['dense_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_14 (TFOpLambda)     (None, 19, 19, 1)    0           ['batch_normalization_20[0][0]']
#
#  tf.nn.silu_15 (TFOpLambda)     (None, 64)           0           ['batch_normalization_21[0][0]']
#
#  flatten (Flatten)              (None, 361)          0           ['tf.nn.silu_14[0][0]']
#
#  dropout_6 (Dropout)            (None, 64)           0           ['tf.nn.silu_15[0][0]']
#
#  policy (Activation)            (None, 361)          0           ['flatten[0][0]']
#
#  value (Dense)                  (None, 1)            65          ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 485,541
# Trainable params: 482,851
# Non-trainable params: 2,690
# __________________________________________________________________________________________________
# getting validation...
# r.shape = (10000, 19, 19, 31)
# nbExamples = 10000
    policy_acc = get_metric(history,'policy_categorical_accuracy')

    # MSE 
    value_mse = get_metric(history,'value_mse')
    


    fig,(ax_loss,ax_acc,ax_mse) = plt.subplots(1,3)
    fig.set_size_inches((16,4))

    # Losses 
    ax_loss.plot(epochs, loss ,'c',label = 'Loss')
    ax_loss.plot(epochs, value_loss, 'g' , label = 'Value Loss')
    ax_loss.plot(epochs, policy_loss ,'r',label = 'Policy Loss')
    ax_loss.set_title('Losses History ')
    ax_loss.legend()

    # Accuracy
    ax_acc.plot(epochs, policy_acc , 'r',label = 'Policy Accuracy')
    ax_acc.set_title('Policy Accuracy History ')
    ax_acc.legend()

    # MSE
    ax_mse.plot(epochs, value_mse , 'g',label = 'Value MSE')
    ax_mse.set_title('Value MSE History ')
    ax_mse.legend()

    fig.show()





epochs = list(history.keys())
plots(epochs,history)

# %%
# !python train.py
# Out:
# tcmalloc: large alloc 1790566400 bytes == 0x5564adcc6000 @  0x7f659098f1e7 0x7f654db2c46e 0x7f654db7cc7b 0x7f654db7d35f 0x7f654dc1f103 0x5564a674f2eb 0x7f652fb3b44c 0x7f652fb66b03 0x7f653021f9b8 0x5564a680e544 0x5564a680e240 0x5564a6882627 0x5564a680fafa 0x5564a687dc0d 0x5564a687c9ee 0x5564a687c6f3 0x5564a69464c2 0x5564a694683d 0x5564a69466e6 0x5564a691e163 0x5564a691de0c 0x7f658f779bf7 0x5564a691dcea
# 2021-11-20 10:47:25.114833: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  board (InputLayer)             [(None, 19, 19, 31)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 19, 19, 64)   2048        ['board[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 64)   17920       ['board[0][0]']
#
#  batch_normalization (BatchNorm  (None, 19, 19, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  tf.nn.silu (TFOpLambda)        (None, 19, 19, 64)   0           ['batch_normalization[0][0]']
#
#  tf.nn.silu_1 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 19, 19, 64)   0           ['tf.nn.silu[0][0]',
#                                                                   'tf.nn.silu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  tf.nn.silu_2 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 64)          0           ['dropout[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 16)           1040        ['global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 64)           1088        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]',
#                                                                   'dense_1[0][0]']
#
#  add_1 (Add)                    (None, 19, 19, 64)   0           ['multiply[0][0]',
#                                                                   'add[0][0]']
#
#  tf.nn.silu_3 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 19, 19, 64)  256         ['tf.nn.silu_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  tf.nn.silu_4 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_6[0][0]']
#
#  global_max_pooling2d_1 (Global  (None, 64)          0           ['dropout_1[0][0]']
#  MaxPooling2D)
#
#  dense_2 (Dense)                (None, 16)           1040        ['global_max_pooling2d_1[0][0]']
#
#  dense_3 (Dense)                (None, 64)           1088        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'dense_3[0][0]']
#
#  add_2 (Add)                    (None, 19, 19, 64)   0           ['multiply_1[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  tf.nn.silu_5 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 19, 19, 64)  256         ['tf.nn.silu_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  tf.nn.silu_6 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_9[0][0]']
#
#  global_max_pooling2d_2 (Global  (None, 64)          0           ['dropout_2[0][0]']
#  MaxPooling2D)
#
#  dense_4 (Dense)                (None, 16)           1040        ['global_max_pooling2d_2[0][0]']
#
#  dense_5 (Dense)                (None, 64)           1088        ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_9[0][0]',
#                                                                   'dense_5[0][0]']
#
#  add_3 (Add)                    (None, 19, 19, 64)   0           ['multiply_2[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  tf.nn.silu_7 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_7[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 19, 19, 64)  256         ['conv2d_8[0][0]']
#  ormalization)
#
#  tf.nn.silu_8 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 19, 19, 64)  256         ['conv2d_9[0][0]']
#  ormalization)
#
#  dropout_3 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_12[0][0]']
#
#  global_max_pooling2d_3 (Global  (None, 64)          0           ['dropout_3[0][0]']
#  MaxPooling2D)
#
#  dense_6 (Dense)                (None, 16)           1040        ['global_max_pooling2d_3[0][0]']
#
#  dense_7 (Dense)                (None, 64)           1088        ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_12[0][0]',
#                                                                   'dense_7[0][0]']
#
#  add_4 (Add)                    (None, 19, 19, 64)   0           ['multiply_3[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  tf.nn.silu_9 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_4[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_9[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 19, 19, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  tf.nn.silu_10 (TFOpLambda)     (None, 19, 19, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 19, 19, 64)   36928       ['tf.nn.silu_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 19, 19, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  dropout_4 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_15[0][0]']
#
#  global_max_pooling2d_4 (Global  (None, 64)          0           ['dropout_4[0][0]']
#  MaxPooling2D)
#
#  dense_8 (Dense)                (None, 16)           1040        ['global_max_pooling2d_4[0][0]']
#
#  dense_9 (Dense)                (None, 64)           1088        ['dense_8[0][0]']
#
#  multiply_4 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_15[0][0]',
#                                                                   'dense_9[0][0]']
#
#  add_5 (Add)                    (None, 19, 19, 64)   0           ['multiply_4[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  tf.nn.silu_11 (TFOpLambda)     (None, 19, 19, 64)   0           ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_11[0][0]']
#  ormalization)
#
#  conv2d_12 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 19, 19, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_12 (TFOpLambda)     (None, 19, 19, 64)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 19, 19, 64)   36928       ['tf.nn.silu_12[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 19, 19, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  dropout_5 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_18[0][0]']
#
#  global_max_pooling2d_5 (Global  (None, 64)          0           ['dropout_5[0][0]']
#  MaxPooling2D)
#
#  dense_10 (Dense)               (None, 16)           1040        ['global_max_pooling2d_5[0][0]']
#
#  dense_11 (Dense)               (None, 64)           1088        ['dense_10[0][0]']
#
#  multiply_5 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_18[0][0]',
#                                                                   'dense_11[0][0]']
#
#  add_6 (Add)                    (None, 19, 19, 64)   0           ['multiply_5[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  tf.nn.silu_13 (TFOpLambda)     (None, 19, 19, 64)   0           ['add_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_13[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['batch_normalization_19[0][0]']
#  alAveragePooling2D)
#
#  conv2d_14 (Conv2D)             (None, 19, 19, 1)    64          ['batch_normalization_19[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization_20 (BatchN  (None, 19, 19, 1)   4           ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 64)          256         ['dense_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_14 (TFOpLambda)     (None, 19, 19, 1)    0           ['batch_normalization_20[0][0]']
#
#  tf.nn.silu_15 (TFOpLambda)     (None, 64)           0           ['batch_normalization_21[0][0]']
#
#  flatten (Flatten)              (None, 361)          0           ['tf.nn.silu_14[0][0]']
#
#  dropout_6 (Dropout)            (None, 64)           0           ['tf.nn.silu_15[0][0]']
#
#  policy (Activation)            (None, 361)          0           ['flatten[0][0]']
#
#  value (Dense)                  (None, 1)            65          ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 485,541
# Trainable params: 482,851
# Non-trainable params: 2,690
# __________________________________________________________________________________________________
# getting validation...
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# tcmalloc: large alloc 2400002048 bytes == 0x55654dedc000 @  0x7f6590991887 0x7f64ea1810d9 0x7f64ea18685f 0x7f64ea19b06f 0x5564a680e4b0 0x5564a680e240 0x5564a68820f3 0x5564a687c9ee 0x5564a687c6f3 0x5564a69464c2 0x5564a694683d 0x5564a69466e6 0x5564a691e163 0x5564a691de0c 0x7f658f779bf7 0x5564a691dcea
# nbPositionsSGF = 29425326
# nbPositionsSGF = 29425326
# loading validation.data
#  Epoch [1]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 26s 45ms/step - loss: 4.0832 - policy_loss: 3.7248 - value_loss: 0.7042 - policy_categorical_accuracy: 0.2167 - value_mse: 0.1234
#  Epoch [2]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 3.3583 - policy_loss: 3.0102 - value_loss: 0.6886 - policy_categorical_accuracy: 0.3088 - value_mse: 0.1181
#  Epoch [3]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 3.2040 - policy_loss: 2.8595 - value_loss: 0.6835 - policy_categorical_accuracy: 0.3289 - value_mse: 0.1157
#  Epoch [4]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 3.1064 - policy_loss: 2.7642 - value_loss: 0.6782 - policy_categorical_accuracy: 0.3390 - value_mse: 0.1131
#  Epoch [5]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 3.0389 - policy_loss: 2.7005 - value_loss: 0.6708 - policy_categorical_accuracy: 0.3514 - value_mse: 0.1097
#  Epoch [6]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.9873 - policy_loss: 2.6497 - value_loss: 0.6693 - policy_categorical_accuracy: 0.3564 - value_mse: 0.1089
#  Epoch [7]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.9454 - policy_loss: 2.6096 - value_loss: 0.6655 - policy_categorical_accuracy: 0.3631 - value_mse: 0.1072
#  Epoch [8]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.9168 - policy_loss: 2.5801 - value_loss: 0.6672 - policy_categorical_accuracy: 0.3645 - value_mse: 0.1079
#  Epoch [9]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.8710 - policy_loss: 2.5343 - value_loss: 0.6669 - policy_categorical_accuracy: 0.3729 - value_mse: 0.1078
#  Epoch [10]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.8446 - policy_loss: 2.5095 - value_loss: 0.6637 - policy_categorical_accuracy: 0.3775 - value_mse: 0.1064
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
#  Validation : [3.0321013927459717, 2.637014150619507, 0.7834451198577881, 0.3630000054836273, 0.15536221861839294]
#  Epoch [11]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2

# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.4252 - policy_loss: 2.0971 - value_loss: 0.6482 - policy_categorical_accuracy: 0.4493 - value_mse: 0.0996
#  Epoch [33]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3964 - policy_loss: 2.0679 - value_loss: 0.6488 - policy_categorical_accuracy: 0.4509 - value_mse: 0.0999
#  Epoch [34]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3779 - policy_loss: 2.0481 - value_loss: 0.6512 - policy_categorical_accuracy: 0.4566 - value_mse: 0.1007
#  Epoch [35]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3582 - policy_loss: 2.0286 - value_loss: 0.6506 - policy_categorical_accuracy: 0.4591 - value_mse: 0.1006
#  Epoch [36]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3532 - policy_loss: 2.0242 - value_loss: 0.6493 - policy_categorical_accuracy: 0.4629 - value_mse: 0.1001
#  Epoch [37]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3336 - policy_loss: 2.0046 - value_loss: 0.6495 - policy_categorical_accuracy: 0.4650 - value_mse: 0.1002
#  Epoch [38]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3053 - policy_loss: 1.9773 - value_loss: 0.6476 - policy_categorical_accuracy: 0.4694 - value_mse: 0.0991
#  Epoch [39]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3070 - policy_loss: 1.9778 - value_loss: 0.6496 - policy_categorical_accuracy: 0.4686 - value_mse: 0.1000
#  Epoch [40]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2857 - policy_loss: 1.9574 - value_loss: 0.6477 - policy_categorical_accuracy: 0.4765 - value_mse: 0.0990
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
#  Validation : [3.1754767894744873, 2.7962803840637207, 0.7496135234832764, 0.344650000333786, 0.1339375078678131]
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
import pickle 
import matplotlib.pyplot as plt


with open('DGV0_history', 'rb') as f_hist:
    history = pickle.load(f_hist)



def get_metric(d,key):
    return [v[key][0] for _,v in d.items()]

def plots(epochs , history):
    
    # metrics = ['loss','policy_loss','value_loss','policy_categorical_accuracy','value_mse']
    
    # Losses
    loss = get_metric(history,'loss')
    policy_loss = get_metric(history,'policy_loss')
    value_loss = get_metric(history,'value_mse')

    # Accuracy 
    policy_acc = get_metric(history,'policy_categorical_accuracy')

    # MSE 
    value_mse = get_metric(history,'value_mse')
    


    fig,(ax_loss,ax_acc,ax_mse) = plt.subplots(1,3)
    fig.set_size_inches((16,4))

    # Losses 
    ax_loss.plot(epochs, loss ,'c',label = 'Loss')
    ax_loss.plot(epochs, value_loss, 'g' , label = 'Value Loss')
    ax_loss.plot(epochs, policy_loss ,'r',label = 'Policy Loss')
    ax_loss.set_title('Losses History ')
    ax_loss.legend()

    # Accuracy
    ax_acc.plot(epochs, policy_acc , 'r',label = 'Policy Accuracy')
    ax_acc.set_title('Policy Accuracy History ')
    ax_acc.legend()

    # MSE
    ax_mse.plot(epochs, value_mse , 'g',label = 'Value MSE')
    ax_mse.set_title('Value MSE History ')
    ax_mse.legend()

    fig.show()





epochs = list(history.keys())
plots(epochs,history)

# %%
# !python train.py
# Out:
# tcmalloc: large alloc 1790566400 bytes == 0x56472cdc0000 @  0x7f8d18ef81e7 0x7f8cd609546e 0x7f8cd60e5c7b 0x7f8cd60e635f 0x7f8cd6188103 0x56472543f2eb 0x7f8cb80a444c 0x7f8cb80cfb03 0x7f8cb87889b8 0x5647254fe544 0x5647254fe240 0x564725572627 0x5647254ffafa 0x56472556dc0d 0x56472556c9ee 0x56472556c6f3 0x5647256364c2 0x56472563683d 0x5647256366e6 0x56472560e163 0x56472560de0c 0x7f8d17ce2bf7 0x56472560dcea
# 2021-11-20 11:09:43.425164: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  board (InputLayer)             [(None, 19, 19, 31)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 19, 19, 64)   2048        ['board[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 64)   17920       ['board[0][0]']
#
#  batch_normalization (BatchNorm  (None, 19, 19, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  tf.nn.silu (TFOpLambda)        (None, 19, 19, 64)   0           ['batch_normalization[0][0]']
#
#  tf.nn.silu_1 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 19, 19, 64)   0           ['tf.nn.silu[0][0]',
#                                                                   'tf.nn.silu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  tf.nn.silu_2 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 64)          0           ['dropout[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 16)           1040        ['global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 64)           1088        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 19, 19, 64)   0           ['batch_normalization_3[0][0]',
#                                                                   'dense_1[0][0]']
#
#  add_1 (Add)                    (None, 19, 19, 64)   0           ['multiply[0][0]',
#                                                                   'add[0][0]']
#
#  tf.nn.silu_3 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 19, 19, 64)  256         ['tf.nn.silu_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  tf.nn.silu_4 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_6[0][0]']
#
#  global_max_pooling2d_1 (Global  (None, 64)          0           ['dropout_1[0][0]']
#  MaxPooling2D)
#
#  dense_2 (Dense)                (None, 16)           1040        ['global_max_pooling2d_1[0][0]']
#
#  dense_3 (Dense)                (None, 64)           1088        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'dense_3[0][0]']
#
#  add_2 (Add)                    (None, 19, 19, 64)   0           ['multiply_1[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  tf.nn.silu_5 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 19, 19, 64)  256         ['tf.nn.silu_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  tf.nn.silu_6 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 19, 19, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_9[0][0]']
#
#  global_max_pooling2d_2 (Global  (None, 64)          0           ['dropout_2[0][0]']
#  MaxPooling2D)
#
#  dense_4 (Dense)                (None, 16)           1040        ['global_max_pooling2d_2[0][0]']
#
#  dense_5 (Dense)                (None, 64)           1088        ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_9[0][0]',
#                                                                   'dense_5[0][0]']
#
#  add_3 (Add)                    (None, 19, 19, 64)   0           ['multiply_2[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  tf.nn.silu_7 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_7[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)              (None, 19, 19, 64)   36928       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 19, 19, 64)  256         ['conv2d_8[0][0]']
#  ormalization)
#
#  tf.nn.silu_8 (TFOpLambda)      (None, 19, 19, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 19, 19, 64)   36928       ['tf.nn.silu_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 19, 19, 64)  256         ['conv2d_9[0][0]']
#  ormalization)
#
#  dropout_3 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_12[0][0]']
#
#  global_max_pooling2d_3 (Global  (None, 64)          0           ['dropout_3[0][0]']
#  MaxPooling2D)
#
#  dense_6 (Dense)                (None, 16)           1040        ['global_max_pooling2d_3[0][0]']
#
#  dense_7 (Dense)                (None, 64)           1088        ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_12[0][0]',
#                                                                   'dense_7[0][0]']
#
#  add_4 (Add)                    (None, 19, 19, 64)   0           ['multiply_3[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  tf.nn.silu_9 (TFOpLambda)      (None, 19, 19, 64)   0           ['add_4[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_9[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 19, 19, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  tf.nn.silu_10 (TFOpLambda)     (None, 19, 19, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 19, 19, 64)   36928       ['tf.nn.silu_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 19, 19, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  dropout_4 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_15[0][0]']
#
#  global_max_pooling2d_4 (Global  (None, 64)          0           ['dropout_4[0][0]']
#  MaxPooling2D)
#
#  dense_8 (Dense)                (None, 16)           1040        ['global_max_pooling2d_4[0][0]']
#
#  dense_9 (Dense)                (None, 64)           1088        ['dense_8[0][0]']
#
#  multiply_4 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_15[0][0]',
#                                                                   'dense_9[0][0]']
#
#  add_5 (Add)                    (None, 19, 19, 64)   0           ['multiply_4[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  tf.nn.silu_11 (TFOpLambda)     (None, 19, 19, 64)   0           ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_11[0][0]']
#  ormalization)
#
#  conv2d_12 (Conv2D)             (None, 19, 19, 64)   36928       ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 19, 19, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_12 (TFOpLambda)     (None, 19, 19, 64)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 19, 19, 64)   36928       ['tf.nn.silu_12[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 19, 19, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  dropout_5 (Dropout)            (None, 19, 19, 64)   0           ['batch_normalization_18[0][0]']
#
#  global_max_pooling2d_5 (Global  (None, 64)          0           ['dropout_5[0][0]']
#  MaxPooling2D)
#
#  dense_10 (Dense)               (None, 16)           1040        ['global_max_pooling2d_5[0][0]']
#
#  dense_11 (Dense)               (None, 64)           1088        ['dense_10[0][0]']
#
#  multiply_5 (Multiply)          (None, 19, 19, 64)   0           ['batch_normalization_18[0][0]',
#                                                                   'dense_11[0][0]']
#
#  add_6 (Add)                    (None, 19, 19, 64)   0           ['multiply_5[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  tf.nn.silu_13 (TFOpLambda)     (None, 19, 19, 64)   0           ['add_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 19, 19, 64)  256         ['tf.nn.silu_13[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['batch_normalization_19[0][0]']
#  alAveragePooling2D)
#
#  conv2d_14 (Conv2D)             (None, 19, 19, 1)    64          ['batch_normalization_19[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization_20 (BatchN  (None, 19, 19, 1)   4           ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 64)          256         ['dense_12[0][0]']
#  ormalization)
#
#  tf.nn.silu_14 (TFOpLambda)     (None, 19, 19, 1)    0           ['batch_normalization_20[0][0]']
#
#  tf.nn.silu_15 (TFOpLambda)     (None, 64)           0           ['batch_normalization_21[0][0]']
#
#  flatten (Flatten)              (None, 361)          0           ['tf.nn.silu_14[0][0]']
#
#  dropout_6 (Dropout)            (None, 64)           0           ['tf.nn.silu_15[0][0]']
#
#  policy (Activation)            (None, 361)          0           ['flatten[0][0]']
#
#  value (Dense)                  (None, 1)            65          ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 485,541
# Trainable params: 482,851
# Non-trainable params: 2,690
# __________________________________________________________________________________________________
# getting validation...
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000

# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3381 - policy_loss: 2.0088 - value_loss: 0.6504 - policy_categorical_accuracy: 0.4615 - value_mse: 0.1005
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
#  Validation : [3.0705649852752686, 2.696836233139038, 0.7394999265670776, 0.358599990606308, 0.13550879061222076]
#  Epoch [41]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3223 - policy_loss: 1.9932 - value_loss: 0.6502 - policy_categorical_accuracy: 0.4648 - value_mse: 0.1004
#  Epoch [42]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.3103 - policy_loss: 1.9812 - value_loss: 0.6500 - policy_categorical_accuracy: 0.4676 - value_mse: 0.1004
#  Epoch [43]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2926 - policy_loss: 1.9628 - value_loss: 0.6514 - policy_categorical_accuracy: 0.4712 - value_mse: 0.1010
#  Epoch [44]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2853 - policy_loss: 1.9566 - value_loss: 0.6490 - policy_categorical_accuracy: 0.4703 - value_mse: 0.0999
#  Epoch [45]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2624 - policy_loss: 1.9333 - value_loss: 0.6501 - policy_categorical_accuracy: 0.4775 - value_mse: 0.1003
#  Epoch [46]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2529 - policy_loss: 1.9242 - value_loss: 0.6492 - policy_categorical_accuracy: 0.4832 - value_mse: 0.0999
#  Epoch [47]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2513 - policy_loss: 1.9211 - value_loss: 0.6520 - policy_categorical_accuracy: 0.4828 - value_mse: 0.1011
#  Epoch [48]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2364 - policy_loss: 1.9079 - value_loss: 0.6488 - policy_categorical_accuracy: 0.4814 - value_mse: 0.0997
#  Epoch [49]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2122 - policy_loss: 1.8845 - value_loss: 0.6468 - policy_categorical_accuracy: 0.4880 - value_mse: 0.0988
#  Epoch [50]
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
# 157/157 [==============================] - 7s 44ms/step - loss: 2.2043 - policy_loss: 1.8753 - value_loss: 0.6493 - policy_categorical_accuracy: 0.4911 - value_mse: 0.1000
# r.shape = (20000, 19, 19, 31)
# nbExamples = 20000
#  Validation : [3.2453651428222656, 2.76869535446167, 0.944891095161438, 0.35635000467300415, 0.1839258223772049]
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
import pickle 
import matplotlib.pyplot as plt


with open('DGV0_history', 'rb') as f_hist:
    history = pickle.load(f_hist)



def get_metric(d,key):
    return [v[key][0] for _,v in d.items()]

def plots(epochs , history):
    
    # metrics = ['loss','policy_loss','value_loss','policy_categorical_accuracy','value_mse']
    
    # Losses
    loss = get_metric(history,'loss')
    policy_loss = get_metric(history,'policy_loss')
    value_loss = get_metric(history,'value_mse')

    # Accuracy 
    policy_acc = get_metric(history,'policy_categorical_accuracy')

    # MSE 
    value_mse = get_metric(history,'value_mse')
    


    fig,(ax_loss,ax_acc,ax_mse) = plt.subplots(1,3)
    fig.set_size_inches((16,4))

    # Losses 
    ax_loss.plot(epochs, loss ,'c',label = 'Loss')
    ax_loss.plot(epochs, value_loss, 'g' , label = 'Value Loss')
    ax_loss.plot(epochs, policy_loss ,'r',label = 'Policy Loss')
    ax_loss.set_title('Losses History ')
    ax_loss.legend()

    # Accuracy
    ax_acc.plot(epochs, policy_acc , 'r',label = 'Policy Accuracy')
    ax_acc.set_title('Policy Accuracy History ')
    ax_acc.legend()

    # MSE
    ax_mse.plot(epochs, value_mse , 'g',label = 'Value MSE')
    ax_mse.set_title('Value MSE History ')
    ax_mse.legend()

    fig.show()





epochs = list(history.keys())
plots(epochs,history)
